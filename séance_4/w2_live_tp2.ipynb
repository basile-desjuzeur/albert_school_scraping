# %%
import pandas as pd 
import requests
import re
from bs4 import BeautifulSoup

# %%
url = "https://books.toscrape.com/"

response = requests.get(url)

response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->\n    <head>\n        <title>\n    All products | Books to Scrape - Sandbox\n</title>\n\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n        <meta name="created" content="24th Jun 2016 09:29" />\n        <meta name="description" content="" />\n        <meta name="viewport" content="width=device-width" />\n        <meta name="robots" content="NOARCHIVE,NOCACHE" />\n\n        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->\n        <!--[if lt IE 9]>\n        <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>\n        <![endif]-->\n\n        \n            <link rel="shortcut icon" hr
# ...

# %%
type(response.text)
# Out:
# str

# %%
soup = BeautifulSoup(response.text, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.find_all("article", class_="product_pod")
# Out:
# [<article class="product_pod">
#  <div class="image_container">
#  <a href="catalogue/a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
#  </div>
#  <p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£51.77</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
# ...

# %%
len(soup.find_all("article", class_="product_pod"))
# Out:
# 20

# %%
books = soup.find_all("article", class_="product_pod")

# %%
books[0]
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="catalogue/a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">Â£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %%
for book in books : 

    # titre
    # prix
    # nb étoiles

# %%
books[0]
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="catalogue/a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">Â£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %%
books[0].find('h3').find("a")
# Out:
# <a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a>

# %%
books[0].find('h3').find("a").get_text()
# Out:
# 'A Light in the ...'

# %%
type(books[0])
# Out:
# bs4.element.Tag

# %%
books[0].find('h3').find("a")["title"]
# Out:
# 'A Light in the Attic'

# %%
books[0].find('h3').find("a")
# Out:
# <a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a>

# %%
books[0].find('h3').find("a")["href"]
# Out:
# 'catalogue/a-light-in-the-attic_1000/index.html'

# %%
for book in books : 

   print(book.find('h3').find("a")["title"])
# Out:
# A Light in the Attic
# Tipping the Velvet
# Soumission
# Sharp Objects
# Sapiens: A Brief History of Humankind
# The Requiem Red
# The Dirty Little Secrets of Getting Your Dream Job
# The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull
# The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics
# The Black Maria
# Starving Hearts (Triangular Trade Trilogy, #1)
# Shakespeare's Sonnets
# Set Me Free
# Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)
# Rip it Up and Start Again
# Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991
# Olio
# Mesaerion: The Best Science Fiction Stories 1800-1849
# Libertarianism for Beginners
# It's Only the Himalayas

# %% [markdown]
# # Titre 1
#
# ## Prix
#
# ### titre 3

# %%
books[0]
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="catalogue/a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">Â£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %%
books[0].find('p', class_="price_color")
# Out:
# <p class="price_color">Â£51.77</p>

# %%
float(books[0].find('p', class_="price_color").get_text().strip("Â£"))
# Out:
# 51.77

# %%
"    fjije   ".strip(" ")
# Out:
# 'fjije'

# %%
for book in books : 

    print(float(book.find('p', class_="price_color").get_text().strip("Â£")))
# Out:
# 51.77
# 53.74
# 50.1
# 47.82
# 54.23
# 22.65
# 33.34
# 17.93
# 22.6
# 52.15
# 13.99
# 20.66
# 17.46
# 52.29
# 35.02
# 57.25
# 23.88
# 37.59
# 51.33
# 45.17

# %% [markdown]
# ## Etoiles

# %%
books[0]
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="catalogue/a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">Â£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %%
books[0].find("p")
# Out:
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>

# %%
books[0].find("p")["class"]
# Out:
# ['star-rating', 'Three']

# %%
books[0].find("p")["class"][-1]
# Out:
# 'Three'

# %%
dict_map = {
    "One": 1,
    "Two": 2,
    "Three": 3,
    "Four": 4,
    "Five": 5
}

dict_map[books[0].find("p")["class"][-1]]
# Out:
# 3

# %%
dict_map.keys()
# Out:
# dict_keys(['One', 'Two', 'Three', 'Four', 'Five'])

# %%
dict_map.values()
# Out:
# dict_values([1, 2, 3, 4, 5])

# %%
dict_map['One']
# Out:
# 1

# %%
for book in books: 

    print(dict_map[book.find("p")["class"][-1]])
# Out:
# 3
# 1
# 1
# 4
# 5
# 1
# 4
# 3
# 4
# 1
# 2
# 4
# 5
# 5
# 5
# 3
# 1
# 1
# 2
# 2

# %% [markdown]
# ## final

# %%
rows = []

for book in books: 

    titre = book.find('h3').find("a")["title"]
    nb_etoiles = dict_map[book.find("p")["class"][-1]]
    prix = float(book.find('p', class_="price_color").get_text().strip("Â£"))

    rows.append([titre, nb_etoiles, prix])

pd.DataFrame(rows)
# Out:
#                                                     0  1      2
# 0                                A Light in the Attic  3  51.77
# 1                                  Tipping the Velvet  1  53.74
# 2                                          Soumission  1  50.10
# 3                                       Sharp Objects  4  47.82
# 4               Sapiens: A Brief History of Humankind  5  54.23
# 5                                     The Requiem Red  1  22.65
# 6   The Dirty Little Secrets of Getting Your Dream...  4  33.34
# 7   The Coming Woman: A Novel Based on the Life of...  3  17.93
# 8   The Boys in the Boat: Nine Americans and Their...  4  22.60
# 9                                     The Black Maria  1  52.15
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  2  13.99
# 11                              Shakespeare's Sonnets  4  20.66
# 12                                        Set Me Free  5  17.46
# 13  Scott Pilgrim's Precious Little Life (Scott Pi...  5  52.29
# ...

# %% [markdown]
# # PT2

# %%
books[0].a["href"]
# Out:
# 'catalogue/a-light-in-the-attic_1000/index.html'

# %%
books[0].find("a")["href"]
# Out:
# 'catalogue/a-light-in-the-attic_1000/index.html'

# %%
type(books)
# Out:
# bs4.element.ResultSet

# %%
len(books)
# Out:
# 20

# %%
url_base = "https://books.toscrape.com/"
url_produit = books[0].find("a")["href"]
url_complet = url_base + url_produit

url_complet
# Out:
# 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'

# %%
response_produit = requests.get(url_complet)

print(response_produit.status_code)

soup_produit = BeautifulSoup(response_produit.text, "html.parser")
# Out:
# 200

# %%
soup_produit
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     A Light in the Attic | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="
# ...

# %%
soup_produit.find("ul", class_="breadcrumb")
# Out:
# <ul class="breadcrumb">
# <li>
# <a href="../../index.html">Home</a>
# </li>
# <li>
# <a href="../category/books_1/index.html">Books</a>
# </li>
# <li>
# <a href="../category/books/poetry_23/index.html">Poetry</a>
# </li>
# <li class="active">A Light in the Attic</li>
# </ul>

# %%
soup_produit.find_all("ul", class_="breadcrumb")
# Out:
# [<ul class="breadcrumb">
#  <li>
#  <a href="../../index.html">Home</a>
#  </li>
#  <li>
#  <a href="../category/books_1/index.html">Books</a>
#  </li>
#  <li>
#  <a href="../category/books/poetry_23/index.html">Poetry</a>
#  </li>
#  <li class="active">A Light in the Attic</li>
#  </ul>]

# %%
len(soup_produit.find_all("ul", class_="breadcrumb"))
# Out:
# 1

# %%
soup_produit.find_all("ul", class_="breadcrumb")[0]
# Out:
# <ul class="breadcrumb">
# <li>
# <a href="../../index.html">Home</a>
# </li>
# <li>
# <a href="../category/books_1/index.html">Books</a>
# </li>
# <li>
# <a href="../category/books/poetry_23/index.html">Poetry</a>
# </li>
# <li class="active">A Light in the Attic</li>
# </ul>

# %%
soup_produit.find("ul", class_="breadcrumb")
# Out:
# <ul class="breadcrumb">
# <li>
# <a href="../../index.html">Home</a>
# </li>
# <li>
# <a href="../category/books_1/index.html">Books</a>
# </li>
# <li>
# <a href="../category/books/poetry_23/index.html">Poetry</a>
# </li>
# <li class="active">A Light in the Attic</li>
# </ul>

# %%
soup_produit.find("ul", class_="breadcrumb").find_all("li")
# Out:
# [<li>
#  <a href="../../index.html">Home</a>
#  </li>,
#  <li>
#  <a href="../category/books_1/index.html">Books</a>
#  </li>,
#  <li>
#  <a href="../category/books/poetry_23/index.html">Poetry</a>
#  </li>,
#  <li class="active">A Light in the Attic</li>]

# %%
soup_produit.find("ul", class_="breadcrumb").find_all("li")[-2]
# Out:
# <li>
# <a href="../category/books/poetry_23/index.html">Poetry</a>
# </li>

# %%
soup_produit.find("ul", class_="breadcrumb").find_all("li")[-2].a
# Out:
# <a href="../category/books/poetry_23/index.html">Poetry</a>

# %%
soup_produit.find("ul", class_="breadcrumb").find_all("li")[-2].get_text().strip('\n')
# Out:
# 'Poetry'

# %%
"poetry".strip("\n")
# Out:
# 'poetry'

# %%
url_produit
# Out:
# 'catalogue/its-only-the-himalayas_981/index.html'

# %%
for book in books: 

    url_base = "https://books.toscrape.com/"
    url_produit = book.find("a")["href"]
    url_complet = url_base + url_produit

    response_produit = requests.get(url_complet)

    soup_produit = BeautifulSoup(response_produit.text, "html.parser")

    print(soup_produit.find("ul", class_="breadcrumb").find_all("li")[-2].get_text().strip('\n'))
# Out:
# Poetry
# Historical Fiction
# Fiction
# Mystery
# History
# Young Adult
# Business
# Default
# Default
# Poetry
# Default
# Poetry
# Young Adult
# Sequential Art
# Music
# Music
# Poetry
# Science Fiction
# Politics
# Travel

# %% [markdown]
# ## Toutes les pages

# %%
for i in range(1, 51):

    url = "https://books.toscrape.com/catalogue/page-" + str(i) + ".html"
    print(url)
# Out:
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-2.html
# https://books.toscrape.com/catalogue/page-3.html
# https://books.toscrape.com/catalogue/page-4.html
# https://books.toscrape.com/catalogue/page-5.html
# https://books.toscrape.com/catalogue/page-6.html
# https://books.toscrape.com/catalogue/page-7.html
# https://books.toscrape.com/catalogue/page-8.html
# https://books.toscrape.com/catalogue/page-9.html
# https://books.toscrape.com/catalogue/page-10.html
# https://books.toscrape.com/catalogue/page-11.html
# https://books.toscrape.com/catalogue/page-12.html
# https://books.toscrape.com/catalogue/page-13.html
# https://books.toscrape.com/catalogue/page-14.html
# https://books.toscrape.com/catalogue/page-15.html
# https://books.toscrape.com/catalogue/page-16.html
# https://books.toscrape.com/catalogue/page-17.html
# https://books.toscrape.com/catalogue/page-18.html
# https://books.toscrape.com/catalogue/page-19.html
# ...
