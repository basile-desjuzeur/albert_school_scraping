# %% [markdown]
# # Demo : scraping and parsing a website
#
# ### 1. inspecting the website
#
# Inspect the following website [source]("https://news.ycombinator.com/")
#
# Copy paste these commandes in the console :
# ```console.log("Hello world");```
#
# ```window.scrollTo({ top: document.body.scrollHeight, behavior: "smooth" });```
#
# ```document.body.style.background = "#111";```
#
# ```document.body.style.color = "#fff";```

# %% [markdown]
# ### 2.Scraping the website page

# %%
import time
import re
import requests
import pandas as pd
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# %%
BASE = "https://news.ycombinator.com/"
HEADERS = {
    "User-Agent": "Mozilla/5.0"
}

# %%
url = f"{BASE}news?p=1"
r = requests.get(url, headers=HEADERS, timeout=20)
r.raise_for_status()

# %%
soup = BeautifulSoup(r.text, "html.parser")

# %%
soup
# Out:
# <html lang="en" op="news"><head><meta content="origin" name="referrer"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><link href="news.css?qJ9W32h7VuXKTHuLDtqT" rel="stylesheet" type="text/css"/><link href="y18.svg" rel="icon"/><link href="rss" rel="alternate" title="RSS" type="application/rss+xml"/><title>Hacker News</title></head><body><center><table bgcolor="#f6f6ef" border="0" cellpadding="0" cellspacing="0" id="hnmain" width="85%"><tr><td bgcolor="#ff6600"><table border="0" cellpadding="0" cellspacing="0" style="padding:2px" width="100%"><tr><td style="width:18px;padding-right:4px"><a href="https://news.ycombinator.com"><img height="18" src="y18.svg" style="border:1px white solid; display:block" width="18"/></a></td><td style="line-height:12pt; height:10px;"><span class="pagetop"><b class="hnname"><a href="news">Hacker News</a></b><a href="newest">new</a> | <a href="front">past</a> | <a href="newcomments">comments</a> | <a href="ask">ask</a> | <a href="show">show</a> | <a href="jobs">jobs</a> | <a href="submit" rel="nofollow">submit</a></span></td><td style="text-align:right;padding-right:4px;"><span class="pagetop"><a href="login?goto=news%3Fp%3D1">login</a></span></td></tr></table></td></tr><tr style="height:10px"></tr><tr id="bigbox"><td><table border="0" cellpadding="0" cellspacing="0"><tr class="athing submission" id="46688971"><td align="right" class="title" valign="top"><span class="rank">1.</span></td><td class="votelinks" valign="top"><center><a href="vote?id=46688971&amp;how=up&amp;goto=news%3Fp%3D1" id="up_46688971"><div class="votearrow" title="upvote"></div></a></center></td><td class="title"><span class="titleline"><a href="https://paulmakeswebsites.com/writing/shadcn-radio-button/">The Overcomplexity of the Shadcn Radio Button</a><span class="sitebit comhead"> (<a href="from?site=paulmakeswebsites.com"><span class="sitestr">paulmakeswebsites.com</span></a>)</span></span></td></tr><tr><td colspan="2"></td><td class="subtext"><span class="subline"><span class="score" id="score_46688971">239 points</span> by <a class="hnuser" href="user?id=dbushell">dbushell</a> <span class="age" title="2026-01-20T07:35:09 1768894509"><a href="item?id=46688971">2 hours ago</a></span> <span id="unv_46688971"></span> | <a href="hide?id=46688971&amp;goto=news%3Fp%3D1">hide</a> | <a href="item?id=46688971">108 comments</a></span></td></tr><tr class="spacer" style="height:5px"></tr><tr class="athing submission" id="46684056"><td align="right" class="title" valign="top"><span class="rank">2.</span></td><td class="votelinks" valign="top"><center><a href="vote?id=46684056&amp;how=up&amp;goto=news%3Fp%3D1" id="up_46684056"><div class="votearrow" title="upvote"></div></a></center></td><td class="title"><span class="titleline"><a href="https://www.swpc.noaa.gov/news/g4-severe-geomagnetic-storm-levels-reached-19-jan-2026">Level S4 solar radiation event</a><span class="sitebit comhead"> (<a href="from?site=noaa.gov"><span class="sitestr">noaa.gov</span></a>)</span></span></td></tr><tr><td colspan="2"></td><td class="subtext"><span class="subline"><span class="score" id="score_46684056">439 points</span> by <a class="hnuser" href="user?id=WorldPeas">WorldPeas</a> <span class="age" title="2026-01-19T20:26:19 1768854379"><a href="item?id=46684056">13 hours ago</a></span> <span id="unv_46684056"></span> | <a href="hide?id=46684056&amp;goto=news%3Fp%3D1">hide</a> | <a href="item?id=46684056">149 comments</a></span></td></tr><tr class="spacer" style="height:5px"></tr><tr class="athing submission" id="46689065"><td align="right" class="title" valign="top"><span class="rank">3.</span></td><td class="votelinks" valign="top"><center><a href="vote?id=46689065&amp;how=up&amp;goto=news%3Fp%3D1" id="up_46689065"><div class="votearrow" title="upvote"></div></a></center></td><td class="title"><span class="titleline"><a href="https://github.com/cakehonolulu/pciem">Linux kernel framework for PCIe device emulation, in userspace</a><s ...
# <center><span class="yclinks"><a href="newsguidelines.html">Guidelines</a> | <a href="newsfaq.html">FAQ</a> | <a href="lists">Lists</a> | <a href="https://github.com/HackerNews/API">API</a> | <a href="security.html">Security</a> | <a href="https://www.ycombinator.com/legal/">Legal</a> | <a href="https://www.ycombinator.com/apply/">Apply to YC</a> | <a href="mailto:hn@ycombinator.com">Contact</a></span><br/><br/>
# <form action="//hn.algolia.com/" method="get">Search: <input autocapitalize="off" autocomplete="off" autocorrect="off" name="q" size="17" spellcheck="false" type="text"/></form></center></td></tr></table></center></body><script src="hn.js?qJ9W32h7VuXKTHuLDtqT" type="text/javascript"></script></html>

# %% [markdown]
# ### 3. Parsing soup

# %%
rows = []

# Each story uses a <tr class="athing"> and the very next <tr> has the subtext
for athing in soup.select("tr.athing"):
    rank_el = athing.select_one("span.rank")
    title_el = athing.select_one("span.titleline > a")

    subtext_row = athing.find_next_sibling("tr")
    subtext = subtext_row.select_one("td.subtext") if subtext_row else None

    points_el = subtext.select_one("span.score") if subtext else None
    author_el = subtext.select_one("a.hnuser") if subtext else None
    age_el = subtext.select_one("span.age") if subtext else None

    # comments link is usually the last <a> in subtext
    comment_links = subtext.select("a") if subtext else []
    comments_el = comment_links[-1] if comment_links else None

    story = {
        "page": 1,
        "rank": int(re.search(r"\d+", rank_el.get_text(strip=True).replace(",", "")).group()) if rank_el else None,
        "title": title_el.get_text(strip=True) if title_el else None,
        "url": title_el["href"] if (title_el and title_el.has_attr("href")) else None,
        "points": int(re.search(r"\d+", points_el.get_text(strip=True).replace(",", "")).group()) if points_el else None,
        "author": author_el.get_text(strip=True) if author_el else None,
        "age": age_el.get_text(strip=True) if age_el else None,
        # "comments_count": int(re.search(r"\d+", comments_el.get_text(strip=True).replace(",", "")).group()) if comments_el else None,
        "hn_item_url": urljoin(BASE, comments_el["href"]) if (comments_el and comments_el.has_attr("href")) else None,
    }
    rows.append(story)

# %%
rows
# Out:
# [{'page': 1,
#   'rank': 1,
#   'title': 'The Overcomplexity of the Shadcn Radio Button',
#   'url': 'https://paulmakeswebsites.com/writing/shadcn-radio-button/',
#   'points': 239,
#   'author': 'dbushell',
#   'age': '2 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46688971'},
#  {'page': 1,
#   'rank': 2,
#   'title': 'Level S4 solar radiation event',
#   'url': 'https://www.swpc.noaa.gov/news/g4-severe-geomagnetic-storm-levels-reached-19-jan-2026',
#   'points': 439,
#   'author': 'WorldPeas',
#   'age': '13 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46684056'},
#  {'page': 1,
#   'rank': 3,
#   'title': 'Linux kernel framework for PCIe device emulation, in userspace',
#   'url': 'https://github.com/cakehonolulu/pciem',
#   'points': 23,
#   'author': '71bw',
#   'age': '2 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46689065'},
#  {'page': 1,
#   'rank': 4,
#   'title': 'Reticulum, a secure and anonymous mesh networking stack',
#   'url': 'https://github.com/markqvist/Reticulum',
#   'points': 211,
#   'author': 'brogu',
#   'age': '10 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46686273'},
#  {'page': 1,
#   'rank': 5,
#   'title': 'Increasing the performance of WebAssembly Text Format parser by 350%',
#   'url': 'https://blog.gplane.win/posts/improve-wat-parser-perf.html',
#   'points': 17,
#   'author': 'gplane',
#   'age': '2 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46629399'},
#  {'page': 1,
#   'rank': 6,
#   'title': 'King – man + woman is queen; but why? (2017)',
#   'url': 'https://p.migdal.pl/blog/2017/01/king-man-woman-queen-why/',
#   'points': 7,
#   'author': 'CGMthrowaway',
#   'age': '2 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46641145'},
#  {'page': 1,
#   'rank': 7,
#   'title': 'x86 prefixes and escape opcodes flowchart',
#   'url': 'https://soc.me/interfaces/x86-prefixes-and-escape-opcodes-flowchart.html',
#   'points': 55,
#   'author': 'gaul',
#   'age': '6 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46687705'},
#  {'page': 1,
#   'rank': 8,
#   'title': 'Apple testing new App Store design that blurs the line between ads and results',
#   'url': 'https://9to5mac.com/2026/01/16/iphone-apple-app-store-search-results-ads-new-design/',
#   'points': 387,
#   'author': 'ksec',
#   'age': '17 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46680974'},
#  {'page': 1,
#   'rank': 9,
#   'title': 'What came first: the CNAME or the A record?',
#   'url': 'https://blog.cloudflare.com/cname-a-record-order-dns-standards/',
#   'points': 368,
#   'author': 'linolevan',
#   'age': '17 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46681611'},
#  {'page': 1,
#   'rank': 10,
#   'title': 'Nanolang: A tiny experimental language designed to be targeted by coding LLMs',
#   'url': 'https://github.com/jordanhubbard/nanolang',
#   'points': 157,
#   'author': 'Scramblejams',
#   'age': '12 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46684958'},
#  {'page': 1,
#   'rank': 11,
#   'title': 'Scaling long-running autonomous coding',
#   'url': 'https://simonwillison.net/2026/Jan/19/scaling-long-running-autonomous-coding/',
#   'points': 100,
#   'author': 'srameshc',
#   'age': '10 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46686418'},
#  {'page': 1,
#   'rank': 12,
#   'title': 'Giving university exams in the age of chatbots',
#   'url': 'https://ploum.net/2026-01-19-exam-with-chatbots.html',
#   'points': 89,
#   'author': 'ploum',
#   'age': '2 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46688954'},
#  {'page': 1,
#   'rank': 13,
#   'title': 'The coming industrialisation of exploit generation with LLMs',
#   'url': 'https://sean.heelan.io/2026/01/18/on-the-coming-industrialisation-of-exploit-generation-with-llms/',
#   'points': 147,
#   'author': 'long',
#   'age': '13 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46676081'},
#  {'page': 1,
#   'rank': 14,
#   'title': "Notes on Apple's Nano Texture (2025)",
#   'url': 'https://jon.bo/posts/nano-texture/',
#   'points': 190,
#   'author': 'dsr12',
#   'age': '16 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46682518'},
#  {'page': 1,
#   'rank': 15,
#   'title': 'Nova Launcher added Facebook and Google Ads tracking',
#   'url': 'https://lemdro.id/post/lemdro.id/35049920',
#   'points': 254,
#   'author': 'celsoazevedo',
#   'age': '9 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46686655'},
#  {'page': 1,
#   'rank': 16,
#   'title': '3D printing my laptop ergonomic setup',
#   'url': 'https://www.ntietz.com/blog/3d-printing-my-laptop-ergonomic-setup/',
#   'points': 68,
#   'author': 'kurinikku',
#   'age': '5 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46686131'},
#  {'page': 1,
#   'rank': 17,
#   'title': 'Show HN: Artificial Ivy in the Browser',
#   'url': 'https://da.nmcardle.com/grow',
#   'points': 72,
#   'author': 'dnmc',
#   'age': '7 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46687504'},
#  {'page': 1,
#   'rank': 18,
#   'title': "British redcoat's lost memoir reveals realities of life as a disabled veteran",
#   'url': 'https://phys.org/news/2026-01-british-redcoat-lost-memoir-reveals.html',
#   'points': 84,
#   'author': 'wglb',
#   'age': '12 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46642458'},
#  {'page': 1,
#   'rank': 19,
#   'title': 'Porsche sold more electrified cars in Europe in 2025 than pure gas-powered cars',
#   'url': 'https://newsroom.porsche.com/en/2026/company/porsche-deliveries-2025-41516.html',
#   'points': 311,
#   'author': 'm463',
#   'age': '9 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46686640'},
#  {'page': 1,
#   'rank': 20,
#   'title': "Kahan on the 8087 and designing Intel's floating point (2016) [video]",
#   'url': 'https://www.youtube.com/watch?v=L-QVgbdt_qg',
#   'points': 22,
#   'author': 'bananaboy',
#   'age': '7 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46630718'},
#  {'page': 1,
#   'rank': 21,
#   'title': 'I was a top 0.01% Cursor user, then switched to Claude Code 2.0',
#   'url': 'https://blog.silennai.com/claude-code',
#   'points': 126,
#   'author': 'SilenN',
#   'age': '13 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46676554'},
#  {'page': 1,
#   'rank': 22,
#   'title': 'Show HN: E80: an 8-bit CPU in structural VHDL',
#   'url': 'https://github.com/Stokpan/E80',
#   'points': 11,
#   'author': 'Axonis',
#   'age': '5 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46662390'},
#  {'page': 1,
#   'rank': 23,
#   'title': 'Prediction markets are ushering in a world in which news becomes about gambling',
#   'url': 'https://www.theatlantic.com/technology/2026/01/america-polymarket-disaster/685662/',
#   'points': 294,
#   'author': 'krustyburger',
#   'age': '1 day ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46670524'},
#  {'page': 1,
#   'rank': 24,
#   'title': 'The assistant axis: situating and stabilizing the character of LLMs',
#   'url': 'https://www.anthropic.com/research/assistant-axis',
#   'points': 94,
#   'author': 'mfiguiere',
#   'age': '13 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46684708'},
#  {'page': 1,
#   'rank': 25,
#   'title': 'Face as a QR Code',
#   'url': 'https://bookofjoe2.blogspot.com/2025/12/your-face-as-qr-code.html',
#   'points': 18,
#   'author': 'surprisetalk',
#   'age': '4 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46646173'},
#  {'page': 1,
#   'rank': 26,
#   'title': 'Targeted Bets: An alternative approach to the job hunt',
#   'url': 'https://www.seanmuirhead.com/blog/targeted-bets',
#   'points': 66,
#   'author': 'seany62',
#   'age': '12 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46684815'},
#  {'page': 1,
#   'rank': 27,
#   'title': 'Understanding ZFS Scrubs and Data Integrity',
#   'url': 'https://klarasystems.com/articles/understanding-zfs-scrubs-and-data-integrity/',
#   'points': 50,
#   'author': 'zdw',
#   'age': '7 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46622090'},
#  {'page': 1,
#   'rank': 28,
#   'title': 'From Nevada to Kansas by Glider',
#   'url': 'https://www.weglide.org/flight/978820',
#   'points': 146,
#   'author': 'sammelaugust',
#   'age': '15 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46641036'},
#  {'page': 1,
#   'rank': 29,
#   'title': 'The microstructure of wealth transfer in prediction markets',
#   'url': 'https://www.jbecker.dev/research/prediction-market-microstructure',
#   'points': 154,
#   'author': 'jonbecker',
#   'age': '18 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46680515'},
#  {'page': 1,
#   'rank': 30,
#   'title': 'Legal Structures for Latin American Startups (2021)',
#   'url': 'https://latamlist.com/legal-structures-for-latin-american-startups/',
#   'points': 28,
#   'author': 'walterbell',
#   'age': '9 hours ago',
#   'hn_item_url': 'https://news.ycombinator.com/item?id=46686745'}]

# %% [markdown]
# ### 4. Display it as a DataFrame

# %%
df = pd.DataFrame(rows)

# quick cleanup / sanity checks
# df["comments_count"] = df["comments_count"].fillna(0).astype(int)
df = df.sort_values(["page", "rank"], ascending=True).reset_index(drop=True)

df.head(10)
# Out:
#    page  rank                                              title  \
# 0     1     1      The Overcomplexity of the Shadcn Radio Button
# 1     1     2                     Level S4 solar radiation event
# 2     1     3  Linux kernel framework for PCIe device emulati...
# 3     1     4  Reticulum, a secure and anonymous mesh network...
# 4     1     5  Increasing the performance of WebAssembly Text...
# 5     1     6       King – man + woman is queen; but why? (2017)
# 6     1     7          x86 prefixes and escape opcodes flowchart
# 7     1     8  Apple testing new App Store design that blurs ...
# 8     1     9        What came first: the CNAME or the A record?
# 9     1    10  Nanolang: A tiny experimental language designe...
#
#                                                  url  points        author  \
# 0  https://paulmakeswebsites.com/writing/shadcn-r...     239      dbushell
# 1  https://www.swpc.noaa.gov/news/g4-severe-geoma...     439     WorldPeas
# 2              https://github.com/cakehonolulu/pciem      23          71bw
# 3             https://github.com/markqvist/Reticulum     211         brogu
# 4  https://blog.gplane.win/posts/improve-wat-pars...      17        gplane
# 5  https://p.migdal.pl/blog/2017/01/king-man-woma...       7  CGMthrowaway
# 6  https://soc.me/interfaces/x86-prefixes-and-esc...      55          gaul
# 7  https://9to5mac.com/2026/01/16/iphone-apple-ap...     387          ksec
# 8  https://blog.cloudflare.com/cname-a-record-ord...     368     linolevan
# 9          https://github.com/jordanhubbard/nanolang     157  Scramblejams
#
#             age                                    hn_item_url
# 0   2 hours ago  https://news.ycombinator.com/item?id=46688971
# 1  13 hours ago  https://news.ycombinator.com/item?id=46684056
# 2   2 hours ago  https://news.ycombinator.com/item?id=46689065
# 3  10 hours ago  https://news.ycombinator.com/item?id=46686273
# 4   2 hours ago  https://news.ycombinator.com/item?id=46629399
# 5   2 hours ago  https://news.ycombinator.com/item?id=46641145
# 6   6 hours ago  https://news.ycombinator.com/item?id=46687705
# 7  17 hours ago  https://news.ycombinator.com/item?id=46680974
# 8  17 hours ago  https://news.ycombinator.com/item?id=46681611
# 9  12 hours ago  https://news.ycombinator.com/item?id=46684958
