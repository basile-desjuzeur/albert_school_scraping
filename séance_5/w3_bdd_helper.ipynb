# %%
import pandas as pd

# %%
df = pd.read_csv("cars_0.csv")

# %% [markdown]
# ## First look

# %%
df.shape
# Out:
# (300, 8)

# %%
df.head()
# Out:
#       car_id  doors  engine_size  mileage  horsepower  has_sunroof  age  price
# 0  CAR000001      4          2.3    57154         185            0    3  34923
# 1  CAR000002      2          1.7   187296         115            1   14   3104
# 2  CAR000003      4          2.0   196147         189            1   14   1200
# 3  CAR000004      3          1.3    70354         167            1    5  26982
# 4  CAR000005      3          3.3   165397         263            0   11  16836

# %%
df.tail()
# Out:
#         car_id  doors  engine_size  mileage  horsepower  has_sunroof  age  \
# 295  CAR000296      4          3.9    78498         285            0    4
# 296  CAR000297      4          4.0    67817         292            0    7
# 297  CAR000298      4          3.1   163102         176            0   12
# 298  CAR000299      4          3.6    98444         275            0    7
# 299  CAR000300      4          3.4   226917         218            0   14
#
#      price
# 295  38302
# 296  31206
# 297   6210
# 298  30592
# 299  14376

# %%
df.columns
# Out:
# Index(['car_id', 'doors', 'engine_size', 'mileage', 'horsepower',
#        'has_sunroof', 'age', 'price'],
#       dtype='object')

# %%
df.sample()
# Out:
#         car_id  doors  engine_size  mileage  horsepower  has_sunroof  age  \
# 149  CAR000150      4          1.5   148335         116            0   15
#
#      price
# 149   3318

# %% [markdown]
# ## Types of the columns

# %%
df.dtypes
# Out:
# car_id          object
# doors            int64
# engine_size    float64
# mileage          int64
# horsepower       int64
# has_sunroof      int64
# age              int64
# price            int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   car_id       300 non-null    object
#  1   doors        300 non-null    int64
#  2   engine_size  300 non-null    float64
#  3   mileage      300 non-null    int64
#  4   horsepower   300 non-null    int64
#  5   has_sunroof  300 non-null    int64
#  6   age          300 non-null    int64
#  7   price        300 non-null    int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 18.9+ KB

# %% [markdown]
# ## Missing values

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# car_id         0
# doors          0
# engine_size    0
# mileage        0
# horsepower     0
# has_sunroof    0
# age            0
# price          0
# dtype: int64

# %%
(df.isna().mean() * 100).sort_values(ascending=False)  # % missing
# Out:
# car_id         0.0
# doors          0.0
# engine_size    0.0
# mileage        0.0
# horsepower     0.0
# has_sunroof    0.0
# age            0.0
# price          0.0
# dtype: float64

# %%
df.isna().sum().plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# ## Duplicates

# %%
df.drop_duplicates().shape
# Out:
# (300, 8)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Basic stats

# %%
df.describe()
# Out:
#             doors  engine_size        mileage  horsepower  has_sunroof  \
# count  300.000000   300.000000     300.000000  300.000000   300.000000
# mean     3.773333     2.658000  107070.613333  201.496667     0.246667
# std      0.759745     0.985227   61663.097975   59.120844     0.431791
# min      2.000000     1.000000       0.000000   71.000000     0.000000
# 25%      4.000000     1.800000   57398.500000  153.750000     0.000000
# 50%      4.000000     2.600000  103945.500000  199.500000     0.000000
# 75%      4.000000     3.400000  153370.750000  247.250000     0.000000
# max      5.000000     4.500000  264866.000000  363.000000     1.000000
#
#               age         price
# count  300.000000    300.000000
# mean     7.626667  25641.983333
# std      4.663308  13502.347363
# min      0.000000   1200.000000
# 25%      3.000000  14891.750000
# 50%      8.000000  26718.500000
# 75%     12.000000  34978.000000
# max     15.000000  55158.000000

# %%
df.describe(percentiles=[0.01, 0.05, 0.5, 0.95, 0.99])
# Out:
#             doors  engine_size        mileage  horsepower  has_sunroof  \
# count  300.000000   300.000000     300.000000  300.000000   300.000000
# mean     3.773333     2.658000  107070.613333  201.496667     0.246667
# std      0.759745     0.985227   61663.097975   59.120844     0.431791
# min      2.000000     1.000000       0.000000   71.000000     0.000000
# 1%       2.000000     1.000000    4342.870000   89.960000     0.000000
# 5%       2.000000     1.200000   15850.050000  114.000000     0.000000
# 50%      4.000000     2.600000  103945.500000  199.500000     0.000000
# 95%      5.000000     4.300000  207979.450000  295.000000     1.000000
# 99%      5.000000     4.500000  242876.270000  322.020000     1.000000
# max      5.000000     4.500000  264866.000000  363.000000     1.000000
#
#               age         price
# count  300.000000    300.000000
# mean     7.626667  25641.983333
# std      4.663308  13502.347363
# min      0.000000   1200.000000
# ...

# %% [markdown]
# ## Categorical exploration

# %%
df["age"].unique()[:20]
# Out:
# array([ 3, 14,  5, 11, 13,  4,  6,  0,  1,  8,  2,  7, 10,  9, 15, 12])

# %%
df["age"].value_counts()
# Out:
# age
# 12    24
# 11    22
# 9     22
# 6     20
# 4     20
# 1     20
# 13    20
# 14    19
# 10    19
# 2     19
# 0     19
# 3     18
# 7     18
# 15    17
# 8     12
# 5     11
# Name: count, dtype: int64

# %%
df["age"].value_counts(normalize=True) * 100
# Out:
# age
# 12    8.000000
# 11    7.333333
# 9     7.333333
# 6     6.666667
# 4     6.666667
# 1     6.666667
# 13    6.666667
# 14    6.333333
# 10    6.333333
# 2     6.333333
# 0     6.333333
# 3     6.000000
# 7     6.000000
# 15    5.666667
# 8     4.000000
# 5     3.666667
# Name: proportion, dtype: float64

# %%
df["age"].nunique()
# Out:
# 16

# %% [markdown]
# ## Check for outliers

# %%
df["price"].min(), df["price"].max()
# Out:
# (np.int64(1200), np.int64(55158))

# %%
df["price"].quantile([0.01, 0.5, 0.99])
# Out:
# 0.01     1200.00
# 0.50    26718.50
# 0.99    51175.21
# Name: price, dtype: float64

# %%
df["price"].plot(kind="hist", bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'doors'}>,
#         <Axes: title={'center': 'engine_size'}>,
#         <Axes: title={'center': 'mileage'}>],
#        [<Axes: title={'center': 'horsepower'}>,
#         <Axes: title={'center': 'has_sunroof'}>,
#         <Axes: title={'center': 'age'}>],
#        [<Axes: title={'center': 'price'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ## GroupBy

# %%
df.groupby("age")["price"].mean().sort_values(ascending=False)
# Out:
# age
# 0     47290.000000
# 1     43436.550000
# 2     40423.894737
# 3     37498.055556
# 4     33010.250000
# 5     30416.454545
# 7     29576.000000
# 6     29369.350000
# 8     25088.583333
# 9     22623.000000
# 10    20976.210526
# 11    17241.909091
# 12    15001.416667
# 13     9131.700000
# 14     7370.210526
# 15     6379.588235
# Name: price, dtype: float64

# %%
df.groupby("age").size().sort_values(ascending=False)
# Out:
# age
# 12    24
# 9     22
# 11    22
# 1     20
# 13    20
# 4     20
# 6     20
# 0     19
# 14    19
# 10    19
# 2     19
# 3     18
# 7     18
# 15    17
# 8     12
# 5     11
# dtype: int64

# %%
df.groupby("age")["price"].agg(["count", "mean", "min", "max"]).sort_values("count", ascending=False)
# Out:
#      count          mean    min    max
# age
# 12      24  15001.416667   5799  23889
# 9       22  22623.000000   9876  34490
# 11      22  17241.909091   5184  30338
# 1       20  43436.550000  36690  51150
# 13      20   9131.700000   1200  15291
# 4       20  33010.250000  24333  43085
# 6       20  29369.350000  23512  36333
# 0       19  47290.000000  40888  55158
# 14      19   7370.210526   1200  18781
# 10      19  20976.210526   8846  30031
# 2       19  40423.894737  32137  48914
# 3       18  37498.055556  29590  45904
# 7       18  29576.000000  21390  38013
# 15      17   6379.588235   1200  15588
# 8       12  25088.583333  18975  32380
# 5       11  30416.454545  22414  42779

# %% [markdown]
# ## Dates

# %%
df["date"].head()
df["date"] = pd.to_datetime(df["date"], errors="coerce")
df["date"].isna().sum()
df["date"].min(), df["date"].max()
